# %% [markdown]
# ## Data Processing Stage 1 After the FSL preprocessing
#
# This stage involves the process of extracting the images from nii files of all categories. Images are stored in respective folder of class labels. This step is done so as to train the Neural network model with the required images.

# %%
import os
import numpy as np
import nibabel as nib
import glob
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
import cv2
import matplotlib.image as mpimg
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score
from skimage import filters
from skimage import measure
from skimage.color import rgb2gray
from skimage.morphology import closing, square

# %% [markdown]
# ## Extract images from nii files into corresponding class and nii file folder

# %% [markdown]
# ## For training and validation purpose

# %%
classes = ['Alzheimer','MCI','Normal']

#home_files_dir = '/home/nagdev/work/siddhant/data/data/'
# home_files_dir = '/home/h_hack/work/pywork/ML/datasets/Alzheimer_detect/fsl_preprocessed/'
#home_files_dir2 = '/home/ec2-user/final_data/niifiles/'
#home_files_dir = '/home/ec2-user/final_data/'
home_files_dir2 = '/home/ubuntu/original_T1/niifiles/'
home_files_dir = '/home/ubuntu/original_T1/'

data = []
labels = []

count = 1
for class_ in classes:
    print ('working on ' + class_ + '...')
    for root, dir ,files in os.walk(os.path.join(home_files_dir2 , class_)):
        try:
            os.mkdir(home_files_dir + 'images/')
        except:
            pass
        try:
            os.mkdir(home_files_dir + 'images/' + class_ + '/')
        except:
            pass
        for file_ in files:
            print 'working on ' + file_ + '...'
            
            try:
                os.mkdir(home_files_dir + 'images/' + class_ + '/' + file_ + '/')
            except:
                pass
            full_path = home_files_dir + 'images/' + class_ + '/' + file_ + '/'
            x = nib.load(os.path.join(home_files_dir2 , class_) + '/' + file_).get_data()
            for i in xrange(x.shape[3]):
                for j in xrange(x.shape[2]):
                        y = x[:, :, j, i]
                        img = Image.fromarray(y)
                        img = img.convert("RGB")
                        img = img.resize([224, 224])
                        img.save(full_path + str(count) + ".jpg")
                        count+=1 
    #os.system('rm -rf %s%s' %(home_files_dir2, class_))
# Out:
# working on Alzheimer...
# working on MCI...
# working on M213_018_S_4597.nii...
# working on M302_031_S_4947.nii...
# working on M100_002_S_4799.nii...
# working on M37_053_S_2396.nii...
# working on M131_006_S_4713.nii...
# working on M335_100_S_4556.nii...
# working on M110_006_S_4363.nii...
# working on M266_031_S_4029.nii...
# working on M50_002_S_0729.nii...
# working on M347_130_S_2391.nii...
# working on M168_130_S_4817.nii...
# working on M177_013_S_4395.nii...
# working on M269_031_S_4042.nii...
# working on M209_018_S_2180.nii...
# working on M90_002_S_4521.nii...
# working on M89_002_S_4473.nii...
# working on M159_12_S_4987.nii...
# working on M176_013_S_4395.nii...
# working on M299_031_S_4721.nii...
# working on M33_130_S_2373.nii...
# working on M75_002_S_4229.nii...
# working on M67_002_S_2073.nii...
# working on M151_012_S_4188.nii...
# working on M251_031_S_2022.nii...
# working on M59_002_S_2010.nii...
# working on M119_006_S_4515.nii...
# working on M136_012_S_4012.nii...
# working on M312_053_S_2396.nii...
# working on M143_012_S_4094.nii...
# working on M206_018_S_2180.nii...
# working on M2_012_S_4012.nii...
# working on M318_053_S_4557.nii...
# working on M205_130_S_4468.nii...
# working on M84_002_S_4447.nii...
# working on M324_130_S_4294.nii...
# working on M4_006_S_4960.nii...
# working on M320_053_S_4661.nii...
# working on M253_031_S_2022.nii...
# working on M120_006_S_4679.nii...
# working on M261_031_S_4005.nii...
# working on M68_002_S_4171.nii...
# working on M338_129_S_4073.nii...
# working on M233_019_S_4293.nii...
# working on M42_031_S_2017.nii...
# working on M234_019_S_4293.nii...
# working on M25_002_S_1155.nii...
# working on M105_006_S_4346.nii...
# working on M154_130_S_4883.nii...
# working on M196_018_S_2133.nii...
# working on M295_031_S_4590.nii...
# working on M217_130_S_4468.nii...
# working on M109_006_S_4363.nii...
# working on M128_130_S_4925.nii...
# working on M211_018_S_4597.nii...
# working on M156_012_S_4849.nii...
# working on M313_053_S_2396.nii...
# working on M8_006_S_4363.nii...
# working on M97_002_S_4746.nii...
# working on M19_002_S_4219.nii...
# working on M292_031_S_4590.nii...
# working on M225_018_S_4889.nii...
# working on M30_130_S_2403.nii...
# working on M179_130_S_4605.nii...
# working on M222_018_S_4889.nii...
# working on M36_013_S_1186.nii...
# working on M158_012_S_4987.nii...
# working on M55_002_S_1268.nii...
# working on M319_130_S_4294.nii...
# working on M262_031_S_4005.nii...
# working on M20_002_S_4171.nii...
# working on M240_130_S_4417_.nii...
# working on M111_136_S_4189.nii...
# working on M187_130_S_4468.nii...
# working on M5_006_S_4713.nii...
# working on M73_002_S_4229.nii...
# working on M44_018_S_2155.nii...
# working on M64_130_S_2391.nii...
# working on M46_018_S_2133.nii...
# working on M138_012_S_4012.nii...
# working on M170_013_S_2389.nii...
# working on M152_012_S_4188.nii...
# working on M16_002_S_4251.nii...
# working on M210_018_S_2180.nii...
# working on M267_031_S_4029.nii...
# working on M145_012_S_4128.nii...
# working on M241_130_S_4417.nii...
# working on M227_130_S_4417.nii...
# working on M58_002_S_2010.nii...
# working on M191_013_S_4917.nii...
# working on M294_130_S_4405.nii...
# working on M153_012_S_4849.nii...
# working on M200_018_S_2138.nii...
# working on M178_013_S_4768.nii...
# working on M272_031_S_4042.nii...
# working on M28_136_S_4848.nii...
# working on M41_031_S_2018.nii...
# working on M212_018_S_4597.nii...
# working on M247_031_S_2018.nii...
# working on M337_100_S_4970.nii...
# working on M276_031_S_4149.nii...
# working on M297_031_S_4721.nii...
# working on M304_130_S_4294.nii...
# working on M122_130_S_4925.nii...
# working on M252_031_S_2022.nii...
# working on M334_100_S_4556.nii...
# working on M106_136_S_4517.nii...
# working on M317_053_S_4557.nii...
# working on M328_100_S_4512.nii...
# working on M293_031_S_4590.nii...
# working on M104_130_S_2403.nii...
# working on M63_002_S_2073.nii...
# working on M258_031_S_4005.nii...
# working on M285_031_S_4203.nii...
# working on M147_130_S_4883.nii...
# working on M296_031_S_4721.nii...
# working on M195_018_S_2133.nii...
# working on M116_006_S_4515.nii...
# working on M132_006_S_4960.nii...
# working on M283_031_S_4203.nii...
# working on M6_006_S_4679.nii...
# working on M166_013_S_2324.nii...
# working on M197_018_S_2133.nii...
# working on M11_002_S_4746.nii...
# working on M330_100_S_4512.nii...
# working on M198_018_S_2133.nii...
# working on M229_019_S_4285.nii...
# working on M256_031_S_2233.nii...
# working on M342_130_S_2373.nii...
# working on M117_006_S_4515.nii...
# working on M114_006_S_4363.nii...
# working on M245_031_S_2018.nii...
# working on M208_018_S_2180.nii...
# working on M88_002_S_4473.nii...
# working on M65_002_S_2073.nii...
# working on M246_031_S_2018.nii...
# working on M22_002_S_2043.nii...
# working on M277_031_S_4149.nii...
# working on M62_002_S_2043.nii...
# working on M315_053_S_2396_.nii...
# working on M310_053_S_2357.nii...
# working on M202_018_S_2155.nii...
# working on M165_013_S_2324.nii...
# working on M169_013_S_2389.nii...
# working on M101_002_S_4799.nii...
# working on M118_136_S_0107.nii...
# working on M341_130_S_2373.nii...
# working on M17_002_S_4237.nii...
# working on M13_002_S_4521.nii...
# working on M203_018_S_2155.nii...
# working on M216_018_S_4809.nii...
# working on M248_031_S_2018.nii...
# working on M15_002_S_4447.nii...
# working on M107_006_S_4346.nii...
# working on M271_031_S_4042.nii...
# working on M201_018_S_2155.nii...
# working on M102_006_S_4346.nii...
# working on M340_129_S_4287.nii...
# working on M307_053_S_0919.nii...
# working on M172_013_S_4268.nii...
# working on M134_006_S_4960.nii...
# working on M47_130_S_4250.nii...
# working on M231_019_S_4293.nii...
# working on M76_002_S_4229.nii...
# working on M331_100_S_4512.nii...
# working on M86_002_S_4447.nii...
# working on M80_002_S_4237.nii...
# working on M275_031_S_4149.nii...
# working on M124_130_S_4925.nii...
# working on M51_002_S_0729.nii...
# working on M26_136_S_4836.nii...
# working on M139_012_S_4094.nii...
# working on M40_031_S_2022.nii...
# working on M95_002_S_4654.nii...
# working on M236_019_S_4548.nii...
# working on M264_031_S_4029.nii...
# working on M273_031_S_4149.nii...
# working on M121_006_S_4679.nii...
# working on M183_130_S_4542.nii...
# working on M57_002_S_2010.nii...
# working on M274_031_S_4149.nii...
# working on M148_012_S_4128.nii...
# working on M311_053_S_2357.nii...
# working on M175_130_S_4817.nii...
# working on M249_031_S_2022.nii...
# working on M149_012_S_4188.nii...
# working on M155_012_S_4849.nii...
# working on M339_129_S_4220.nii...
# working on M83_002_S_4447.nii...
# working on M190_013_S_4917.nii...
# working on M182_130_S_4542.nii...
# working on M74_002_S_4229.nii...
# working on M303_031_S_4947.nii...
# working on M244_031_S_2018.nii...
# working on M321_130_S_4294.nii...
# working on M35_136_S_4956.nii...
# working on M127_006_S_4713.nii...
# working on M125_006_S_4679.nii...
# working on M163_013_S_1186.nii...
# working on M300_130_S_4405.nii...
# working on M224_018_S_4889.nii...
# working on M288_031_S_4476.nii...
# working on M23_002_S_2010.nii...
# working on M329_100_S_4512.nii...
# working on M193_013_S_4985.nii...
# working on M12_002_S_4654.nii...
# working on M161_013_S_1186.nii...
# working on M305_041_S_5026.nii...
# working on M112_006_S_4363.nii...
# working on M38_053_S_2357.nii...
# working on M108_136_S_4408.nii...
# working on M29_136_S_4932.nii...
# working on M237_019_S_4548.nii...
# working on M92_002_S_4521.nii...
# working on M204_018_S_2155.nii...
# working on M98_002_S_4746.nii...
# working on M232_019_S_4293.nii...
# working on M219_018_S_4868.nii...
# working on M10_002_S_4799.nii...
# working on M171_013_S_4236.nii...
# working on M173_013_S_4268.nii...
# working on M160_012_S_4987.nii...
# working on M24_002_S_1268.nii...
# working on M189_013_S_4917.nii...
# working on M77_002_S_4237.nii...
# working on M344_130_S_2373.nii...
# working on M336_100_S_4884.nii...
# working on M113_136_S_4189.nii...
# working on M215_018_S_4809.nii...
# working on M290_031_S_4476.nii...
# working on M140_012_S_4094.nii...
# working on M21_002_S_2073.nii...
# working on M268_031_S_4042.nii...
# working on M322_130_S_4294.nii...
# working on M282_130_S_4405.nii...
# working on M238_019_S_4548.nii...
# working on M326_053_S_4813.nii...
# working on M306_053_S_0919.nii...
# working on M185_013_S_4791.nii...
# working on M9_006_S_4346.nii...
# working on M259_031_S_4005.nii...
# working on M144_012_S_4128.nii...
# working on M286_031_S_4203.nii...
# working on M99_002_S_4799.nii...
# working on M278_130_S_4415.nii...
# working on M60_002_S_2010.nii...
# working on M314_053_S_2396.nii...
# working on M284_031_S_4203.nii...
# working on M220_130_S_4417.nii...
# working on M150_012_S_4188.nii...
# working on M257_031_S_2233.nii...
# working on M69_002_S_4171.nii...
# working on M174_013_S_4268.nii...
# working on M162_130_S_4883.nii...
# working on M7_006_S_4515.nii...
# working on M130_130_S_4883.nii...
# working on M298_031_S_4721.nii...
# working on M52_002_S_0729.nii...
# working on M133_006_S_4960.nii...
# working on M85_002_S_4447.nii...
# working on M94_002_S_4654.nii...
# working on M180_130_S_4605.nii...
# working on M223_018_S_4889.nii...
# working on M53_002_S_1155.nii...
# working on M27_013_S_2324.nii...
# working on M1_013_S_2389.nii...
# working on M333_100_S_4556.nii...
# working on M93_002_S_4654.nii...
# working on M239_019_S_4548.nii...
# working on M242_130_S_4417.nii...
# working on M43_018_S_2180.nii...
# working on M281_130_S_4405.nii...
# working on M207_018_S_2180.nii...
# working on M91_002_S_4521.nii...
# working on M280_130_S_4415.nii...
# working on M323_053_S_4661.nii...
# working on M18_002_S_4229.nii...
# working on M186_013_S_4791.nii...
# working on M164_130_S_4817.nii...
# working on M332_100_S_4556.nii...
# working on M14_002_S_4473.nii...
# working on M199_018_S_2138.nii...
# working on M301_031_S_4947.nii...
# working on M78_130_S_2403.nii...
# working on M48_130_S_4250.nii...
# working on M263_031_S_4029.nii...
# working on M39_031_S_2233.nii...
# working on M70_002_S_4219.nii...
# working on M61_002_S_2043.nii...
# working on M221_018_S_4868.nii...
# working on M167_013_S_2324.nii...
# working on M103_006_S_4346.nii...
# working on M279_130_S_4415.nii...
# working on M72_002_S_4219.nii...
# working on M137_012_S_4012.nii...
# working on M316_053_S_4557.nii...
# working on M192_013_S_4985.nii...
# working on M126_130_S_4925.nii...
# working on M49_130_S_4250.nii...
# working on M82_002_S_4251.nii...
# working on M235_019_S_4293.nii...
# working on M129_006_S_4713.nii...
# working on M56_002_S_2010.nii...
# working on M325_053_S_4813.nii...
# working on M66_130_S_2403.nii...
# working on M327_053_S_4813.nii...
# working on M115_006_S_4363.nii...
# working on M289_031_S_4476.nii...
# working on M54_002_S_1155.nii...
# working on M291_031_S_4476.nii...
# working on M343_130_S_2373.nii...
# working on M81_002_S_4251.nii...
# working on M45_018_S_2138.nii...
# working on M146_012_S_4128.nii...
# working on M230_019_S_4285.nii...
# working on M79_130_S_2403.nii...
# working on M228_019_S_4285.nii...
# working on M346_130_S_2391.nii...
# working on M345_130_S_2391.nii...
# working on M243_130_S_4415.nii...
# working on M71_002_S_4219.nii...
# working on M96_002_S_4746.nii...
# working on M308_053_S_2357.nii...
# working on M309_053_S_2357.nii...
# working on M214_018_S_4809.nii...
# working on M87_002_S_4473.nii...
# working on M287_031_S_4203.nii...
# working on M184_130_S_4468.nii...
# working on M260_031_S_4005.nii...
# working on M181_130_S_4542.nii...
# working on M254_031_S_2233.nii...
# working on M226_019_S_4285.nii...
# working on M3_010_S_4135.nii...
# working on M34_100_S_2351.nii...
# working on M141_012_S_4094.nii...
# working on M270_031_S_4042.nii...
# working on M265_031_S_4029.nii...
# working on M157_012_S_4987.nii...
# working on M142_012_S_4094.nii...
# working on M123_006_S_4679.nii...
# working on M32_130_S_4250.nii...
# working on M250_031_S_2022.nii...
# working on M135_006_S_4960.nii...
# working on M31_130_S_2402.nii...
# working on M188_013_S_4917.nii...
# working on M194_018_S_2133.nii...
# working on M218_018_S_4868.nii...
# working on Normal...
# working on N131_013_S_4580.nii...
# working on N31_012_S_4545.nii...
# working on N77_002_S_4270.nii...
# working on N44_130_S_4352.nii...
# working on N75_002_S_4262.nii...
# working on N4_136_S_0186.nii...
# working on N98_006_S_4357.nii...
# working on N28_002_S_4213.nii...
# working on N139_018_S_4257.nii...
# working on N103_031_S_4496.nii...
# working on N128_013_S_4579.nii...
# working on N158_019_S_4367.nii...
# working on N97_053_S_4578.nii...
# working on N129_031_S_4218.nii...
# working on N153_018_S_4399.nii...
# working on N126_012_S_4643.nii...
# working on N109_031_S_4496.nii...
# working on N56_002_S_0685.nii...
# working on N37_019_S_4835.nii...
# working on N17_012_S_4643.nii...
# working on N102_006_S_4449.nii...
# working on N152_018_S_4399.nii...
# working on N62_002_S_1280.nii...
# working on N90_006_S_4357.nii...
# working on N30_010_S_4345.nii...
# working on N136_013_S_4616.nii...
# working on N39_031_S_4474.nii...
# working on N116_010_S_4442.nii...
# working on N111_010_S_4345.nii...
# working on N117_031_S_4496.nii...
# working on N138_013_S_4731.nii...
# working on N14_006_S_4150.nii...
# working on N84_129_S_4371.nii...
# working on N22_031_S_4032.nii...
# working on N155_018_S_4400.nii...
# working on N19_002_S_4270.nii...
# working on N148_018_S_4349.nii...
# working on N54_002_S_0413.nii...
# working on N105_006_S_4485.nii...
# working on N78_002_S_4270.nii...
# working on N91_100_S_4469.nii...
# working on N23_013_S_4616.nii...
# working on N125_012_S_4643.nii...
# working on N92_006_S_4357.nii...
# working on N96_053_S_4578.nii...
# working on N82_129_S_4422.nii...
# working on N67_002_S_4213.nii...
# working on N69_130_S_4343.nii...
# working on N81_006_S_0731.nii...
# working on N15_002_S_4262.nii...
# working on N88_100_S_4469.nii...
# working on N154_018_S_4400.nii...
# working on N135_013_S_4616.nii...
# working on N101_053_S_4578.nii...
# working on N11_100_S_5246.nii...
# working on N3_136_S_4269.nii...
# working on N89_006_S_4150.nii...
# working on N55_002_S_0413.nii...
# working on N25_012_S_4026.nii...
# working on N9_129_S_4369.nii...
# working on N40_031_S_4496.nii...
# working on N13_100_S_4469.nii...
# working on N8_129_S_4371.nii...
# working on N164_031_S_4032.nii...
# working on N141_018_S_4257.nii...
# working on N38_031_S_4218.nii...
# working on N59_002_S_1261.nii...
# working on N2_136_S_4433.nii...
# working on N57_002_S_0685.nii...
# working on N95_006_S_4357.nii...
# working on N65_002_S_4213.nii...
# working on N110_006_S_4485.nii...
# working on N64_002_S_4213.nii...
# working on N168_031_S_4032.nii...
# working on N7_129_S_4396.nii...
# working on N130_013_S_4579.nii...
# working on N147_018_S_4349.nii...
# working on N122_012_S_4545.nii...
# working on N43_130_S_4352.nii...
# working on N76_002_S_4264.nii...
# working on N45_130_S_4352.nii...
# working on N99_006_S_4449.nii...
# working on N21_013_S_4579.nii...
# working on N120_012_S_4026.nii...
# working on N118_031_S_4474.nii...
# working on N87__006_S_4150.nii...
# working on N50_136_S_4726.nii...
# working on N114_010_S_4442.nii...
# working on N32_018_S_4257.nii...
# working on N142_018_S_4313.nii...
# working on N140_018_S_4257.nii...
# working on N157_018_S_4400.nii...
# working on N124_031_S_4218.nii...
# working on N163_019_S_4835.nii...
# working on N48_136_S_4269.nii...
# working on N156_018_S_4400.nii...
# working on N73_002_S_4262.nii...
# working on N35_018_S_4400.nii...
# working on N42_130_S_4352.nii...
# working on N34_018_S_4399.nii...
# working on N6_129_S_4422.nii...
# working on N80_002_S_4270.nii...
# working on N83_006_S_4150.nii...
# working on N33_018_S_4349.nii...
# working on N104_006_S_4449.nii...
# working on N159_019_S_4367.nii...
# working on N112_010_S_4345.nii...
# working on N143_018_S_4313.nii...
# working on N36_019_S_4367.nii...
# working on N16_018_S_4313.nii...
# working on N20_002_S_4225.nii...
# working on N150_018_S_4399.nii...
# working on N71_002_S_4225.nii...
# working on N107_031_S_4496.nii...
# working on N60_002_S_1261.nii...
# working on N127_031_S_4032.nii...
# working on N24_010_S_4442.nii...
# working on N115_010_S_4442.nii...
# working on N52_002_S_0295.nii...
# working on N160_019_S_4367.nii...
# working on N106_006_S_4485.nii...
# working on N134_013_S_4580.nii...
# working on N169_031_S_4032.nii...
# working on N149_18_S_4399.nii...
# working on N132_013_S_4580.nii...
# working on N119_012_S_4026.nii...
# working on N66_002_S_4213.nii...
# working on N29_006_S_4485.nii...
# working on N100_006_S_4449.nii...
# working on N58_130_S_4343.nii...
# working on N151_018_S_4399.nii...
# working on N53_130_S_4343.nii...
# working on N41_130_S_4343.nii...
# working on N166_031_S_4021.nii...
# working on N108_006_S_4485.nii...
# working on N123_012_S_4545.nii...
# working on N167_031_S_4021.nii...
# working on N137_013_S_4616.nii...
# working on N121_031_S_4474.nii...
# working on N165_031_S_4021.nii...
# working on N94_006_S_4357.nii...
# working on N145_018_S_4349.nii...
# working on N46_130_S_4352.nii...
# working on N68_031_S_4218.nii...
# working on N162_019_S_4367.nii...
# working on N85_006_S_4150.nii...
# working on N10_129_S_0778.nii...
# working on N133_031_S_4218.nii...
# working on N70_002_S_4225.nii...
# working on N113_010_S_4345.nii...
# working on N47_136_S_4269.nii...
# working on N51_002_S_0295.nii...
# working on N93_100_S_4469.nii...
# working on N161_019_S_4835.nii...
# working on N61_002_S_1261.nii...
# working on N12_100_S_4511.nii...
# working on N63_002_S_1280.nii...
# working on N144_018_S_4313.nii...
# working on N26_006_S_4449.nii...
# working on N49_136_S_4433.nii...
# working on N1_136_S_4727.nii...
# working on N18_031_S_4021.nii...
# working on N72_002_S_4262.nii...
# working on N146_018_S_4349.nii...
# working on N86_129_S_4369.nii...
# working on N27_002_S_1280.nii...
# working on N79_002_S_4270.nii...
# working on N74_002_S_4262.nii...
# working on N5_130_S_4343.nii...

# %% [markdown]
# ##  Only for testing purpose

# %% [markdown]
# give path of the nii file that you want to test
# and it will convert it to its corresponding images

# %%
# only variable to change
x= nib.load('/home/ubuntu/prediction1case/niifiles/prediction1case/M10_002.nii').get_data()

import shutil
shutil.rmtree('/home/ubuntu/final_data/processed/test_64/')
os.mkdir('/home/ubuntu/final_data/processed/test_64/')
count = 0
for i in xrange(x.shape[3]):
    for j in xrange(x.shape[2]):
        if j > 25 and j < 75:
            continue
        else:
            y = x[:, :, j, i]
            img = Image.fromarray(y)
            img = img.convert("RGB")
            img = img.resize([224, 224])
            img.save('/home/ubuntu/final_data/processed/test_64/' + str(count) + ".jpg")
            count+=1
