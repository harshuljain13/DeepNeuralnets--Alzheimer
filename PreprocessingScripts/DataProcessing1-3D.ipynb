# %% [markdown]
# ## Data Processing Stage 1 After the FSL preprocessing
#
# This stage involves the process of extracting the images from nii files of all categories. Images are stored in respective folder of class labels. This step is done so as to train the Neural network model with the required images.

# %%
import os
import numpy as np
import nibabel as nib
import glob
import shutil
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
import cv2
import matplotlib.image as mpimg
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score
from skimage import filters
from skimage import measure
from skimage.color import rgb2gray
from skimage.morphology import closing, square

# %% [markdown]
# ## Extract images from nii files into corresponding class and nii file folder

# %% [markdown]
# ## For training and validation purpose

# %%
classes = ['Alzheimer', 'MCI', 'Normal']

#home_files_dir = '/home/nagdev/work/siddhant/data/data/'
# home_files_dir = '/home/h_hack/work/pywork/ML/datasets/Alzheimer_detect/fsl_preprocessed/'
#home_files_dir2 = '/home/ec2-user/final_data/niifiles/'
#home_files_dir = '/home/ec2-user/final_data/'
home_files_dir2 = '/home/ubuntu/Select_Normalized-T1_Axial3slices/niifiles/'
home_files_dir = '/home/ubuntu/Select_Normalized-T1_Axial3slices/'

data = []
labels = []

count = 1
for class_ in classes:
    print ('working on ' + class_ + '...')
    for root, dir ,files in os.walk(os.path.join(home_files_dir2 , class_)):
        try:
            os.mkdir(home_files_dir + 'images/')
        except:
            shutil.rmtree(home_files_dir + 'images/')
            os.mkdir(home_files_dir + 'images/')
        try:
            os.mkdir(home_files_dir + 'images/' + class_ + '/')
        except:
            pass
        for file_ in files:
            print 'working on ' + file_ + '...'
            
            try:
                os.mkdir(home_files_dir + 'images/' + class_ + '/' + file_ + '/')
            except:
                pass
            full_path = home_files_dir + 'images/' + class_ + '/' + file_ + '/'
            x = nib.load(os.path.join(home_files_dir2 , class_) + '/' + file_).get_data()
            print x.shape
            for i in xrange(x.shape[1]):
                y = x[:, i, :]
                img = Image.fromarray(y)
                img = img.convert("RGB")
                img = img.resize([224, 224])
                img.save(full_path + 'i_' + str(count) + ".jpg")
                count+=1 
    #os.system('rm -rf %s%s' %(home_files_dir2, class_))
# Out:
# working on Alzheimer...
# working on A53_006_S_4546_normalized-Z.nii...
# (91, 109, 3)
# working on A72_130_S_5059_normalized-Z.nii...
# (91, 109, 3)
# working on A2_131_S_5138_normalized-Z.nii...
# (91, 109, 3)
# working on A58_006_S_4867_normalized-Z.nii...
# (91, 109, 3)
# working on A19_019_S_5019_normalized-Z.nii...
# (91, 109, 3)
# working on A27_018_S_4696_normalized-Z.nii...
# (91, 109, 3)
# working on A15_100_S_5106_normalized-Z.nii...
# (91, 109, 3)
# working on A34_002_S_5018_normalized-Z.nii...
# (91, 109, 3)
# working on A41_130_S_4982_normalized-Z.nii...
# (91, 109, 3)
# working on A6_130_S_4997_normalized-Z.nii...
# (91, 109, 3)
# working on A23_019_S_4252_normalized-Z.nii...
# (91, 109, 3)
# working on A11_130_S_4730_normalized-Z.nii...
# (91, 109, 3)
# working on A104_130_S_4971_normalized-Z.nii...
# (91, 109, 3)
# working on A20_019_S_5012_normalized-Z.nii...
# (91, 109, 3)
# working on A55_130_S_4990_normalized-Z.nii...
# (91, 109, 3)
# working on A48_130_S_4984_normalized-Z.nii...
# (91, 109, 3)
# working on A1_136_S_4993_normalized-Z.nii...
# (91, 109, 3)
# working on A74_019_S_4477_normalized-Z.nii...
# (91, 109, 3)
# working on A98_130_S_4660_normalized-Z.nii...
# (91, 109, 3)
# working on A78_019_S_4549_normalized-Z.nii...
# (91, 109, 3)
# working on A24_018_S_5240_normalized-Z.nii...
# (91, 109, 3)
# working on A18_031_S_4024_normalized-Z.nii...
# (91, 109, 3)
# working on A33_006_S_4153_normalized-Z.nii...
# (91, 109, 3)
# working on A25_018_S_5074_normalized-Z.nii...
# (91, 109, 3)
# working on A45_006_S_4192_normalized-Z.nii...
# (91, 109, 3)
# working on A95_130_S_4641_normalized-Z.nii...
# (91, 109, 3)
# working on A29_010_S_5163_normalized-Z.nii...
# (91, 109, 3)
# working on A16_053_S_5208_normalized-Z.nii...
# (91, 109, 3)
# working on A90_053_S_5070_normalized-Z.nii...
# (91, 109, 3)
# working on A57_130_S_5006_normalized-Z.nii...
# (91, 109, 3)
# working on A93_130_S_4589_normalized-Z.nii...
# (91, 109, 3)
# working on A3_130_S_5231_normalized-Z.nii...
# (91, 109, 3)
# working on A63_013_S_5071_normalized-Z.nii...
# (91, 109, 3)
# working on A26_018_S_4733_normalized-Z.nii...
# (91, 109, 3)
# working on MCI...
# working on M113_136_S_4189_normalized-Z.nii...
# (91, 109, 3)
# working on M305_041_S_5026_normalized-Z.nii...
# (91, 109, 3)
# working on M110_006_S_4363_normalized-Z.nii...
# (91, 109, 3)
# working on M15_002_S_4447_normalized-Z.nii...
# (91, 109, 3)
# working on M268_031_S_4042_normalized-Z.nii...
# (91, 109, 3)
# working on M336_100_S_4884_normalized-Z.nii...
# (91, 109, 3)
# working on M118_136_S_0107_normalized-Z.nii...
# (91, 109, 3)
# working on M288_031_S_4476_normalized-Z.nii...
# (91, 109, 3)
# working on M22_002_S_2043_normalized-Z.nii...
# (91, 109, 3)
# working on M161_013_S_1186_normalized-Z.nii...
# (91, 109, 3)
# working on M162_130_S_4883_normalized-Z.nii...
# (91, 109, 3)
# working on M41_031_S_2018_normalized-Z.nii...
# (91, 109, 3)
# working on M40_031_S_2022_normalized-Z.nii...
# (91, 109, 3)
# working on M3_010_S_4135_normalized-Z.nii...
# (91, 109, 3)
# working on M236_019_S_4548_normalized-Z.nii...
# (91, 109, 3)
# working on M7_006_S_4515_normalized-Z.nii...
# (91, 109, 3)
# working on M63_002_S_2073_normalized-Z.nii...
# (91, 109, 3)
# working on M30_130_S_2403_normalized-Z.nii...
# (91, 109, 3)
# working on M283_031_S_4203_normalized-Z.nii...
# (91, 109, 3)
# working on M52_002_S_0729_normalized-Z.nii...
# (91, 109, 3)
# working on M292_031_S_4590_normalized-Z.nii...
# (91, 109, 3)
# working on M149_012_S_4188_normalized-Z.nii...
# (91, 109, 3)
# working on M28_136_S_4848_normalized-Z.nii...
# (91, 109, 3)
# working on M280_130_S_4415_normalized-Z.nii...
# (91, 109, 3)
# working on M25_002_S_1155_normalized-Z.nii...
# (91, 109, 3)
# working on M300_130_S_4405_normalized-Z.nii...
# (91, 109, 3)
# working on M37_053_S_2396_normalized-Z.nii...
# (91, 109, 3)
# working on M172_013_S_4268_normalized-Z.nii...
# (91, 109, 3)
# working on M328_100_S_4512_normalized-Z.nii...
# (91, 109, 3)
# working on M102_006_S_4346_normalized-Z.nii...
# (91, 109, 3)
# working on M214_018_S_4809_normalized-Z.nii...
# (91, 109, 3)
# working on M144_012_S_4128_normalized-Z.nii...
# (91, 109, 3)
# working on M18_002_S_4229_normalized-Z.nii...
# (91, 109, 3)
# working on M316_053_S_4557_normalized-Z.nii...
# (91, 109, 3)
# working on M29_136_S_4932_normalized-Z.nii...
# (91, 109, 3)
# working on M43_018_S_2180_normalized-Z.nii...
# (91, 109, 3)
# working on M50_002_S_0729_normalized-Z.nii...
# (91, 109, 3)
# working on M45_018_S_2138_normalized-Z.nii...
# (91, 109, 3)
# working on M183_130_S_4542_normalized-Z.nii...
# (91, 109, 3)
# working on M226_019_S_4285_normalized-Z.nii...
# (91, 109, 3)
# working on M153_012_S_4849_normalized-Z.nii...
# (91, 109, 3)
# working on M24_002_S_1268_normalized-Z.nii...
# (91, 109, 3)
# working on M324_130_S_4294_normalized-Z.nii...
# (91, 109, 3)
# working on M188_013_S_4917_normalized-Z.nii...
# (91, 109, 3)
# working on M217_130_S_4468_normalized-Z.nii...
# (91, 109, 3)
# working on M44_018_S_2155_normalized-Z.nii...
# (91, 109, 3)
# working on M23_002_S_2010_normalized-Z.nii...
# (91, 109, 3)
# working on M192_013_S_4985_normalized-Z.nii...
# (91, 109, 3)
# working on M231_019_S_4293_normalized-Z.nii...
# (91, 109, 3)
# working on M14_002_S_4473_normalized-Z.nii...
# (91, 109, 3)
# working on M128_130_S_4925_normalized-Z.nii...
# (91, 109, 3)
# working on M12_002_S_4654_normalized-Z.nii...
# (91, 109, 3)
# working on M273_031_S_4149_normalized-Z.nii...
# (91, 109, 3)
# working on M337_100_S_4970_normalized-Z.nii...
# (91, 109, 3)
# working on M11_002_S_4746_normalized-Z.nii...
# (91, 109, 3)
# working on M171_013_S_4236_normalized-Z.nii...
# (91, 109, 3)
# working on M2_012_S_4012_normalized-Z.nii...
# (91, 109, 3)
# working on M263_031_S_4029_normalized-Z.nii...
# (91, 109, 3)
# working on M175_130_S_4817_normalized-Z.nii...
# (91, 109, 3)
# working on M38_053_S_2357_normalized-Z.nii...
# (91, 109, 3)
# working on M31_130_S_2402_normalized-Z.nii...
# (91, 109, 3)
# working on M338_129_S_4073_normalized-Z.nii...
# (91, 109, 3)
# working on M42_031_S_2017_normalized-Z.nii...
# (91, 109, 3)
# working on M185_013_S_4791_normalized-Z.nii...
# (91, 109, 3)
# working on M16_002_S_4251_normalized-Z.nii...
# (91, 109, 3)
# working on M4_006_S_4960_normalized-Z.nii...
# (91, 109, 3)
# working on M108_136_S_4408_normalized-Z.nii...
# (91, 109, 3)
# working on M33_130_S_2373_normalized-Z.nii...
# (91, 109, 3)
# working on M331_100_S_4512_normalized-Z.nii...
# (91, 109, 3)
# working on M176_013_S_4395_normalized-Z.nii...
# (91, 109, 3)
# working on M332_100_S_4556_normalized-Z.nii...
# (91, 109, 3)
# working on M27_013_S_2324_normalized-Z.nii...
# (91, 109, 3)
# working on M325_053_S_4813_normalized-Z.nii...
# (91, 109, 3)
# working on M35_136_S_4956_normalized-Z.nii...
# (91, 109, 3)
# working on M17_002_S_4237_normalized-Z.nii...
# (91, 109, 3)
# working on M8_006_S_4363_normalized-Z.nii...
# (91, 109, 3)
# working on M301_031_S_4947_normalized-Z.nii...
# (91, 109, 3)
# working on M340_129_S_4287_normalized-Z.nii...
# (91, 109, 3)
# working on M13_002_S_4521_normalized-Z.nii...
# (91, 109, 3)
# working on M242_130_S_4417_normalized-Z.nii...
# (91, 109, 3)
# working on M1_013_S_2389_normalized-Z.nii...
# (91, 109, 3)
# working on M222_018_S_4889_normalized-Z.nii...
# (91, 109, 3)
# working on M211_018_S_4597_normalized-Z.nii...
# (91, 109, 3)
# working on M39_031_S_2233_normalized-Z.nii...
# (91, 109, 3)
# working on M306_053_S_0919_normalized-Z.nii...
# (91, 109, 3)
# working on M139_012_S_4094_normalized-Z.nii...
# (91, 109, 3)
# working on M106_136_S_4517_normalized-Z.nii...
# (91, 109, 3)
# working on M46_018_S_2133_normalized-Z.nii...
# (91, 109, 3)
# working on M10_002_S_4799_normalized-Z.nii...
# (91, 109, 3)
# working on M26_136_S_4836_normalized-Z.nii...
# (91, 109, 3)
# working on M6_006_S_4679_normalized-Z.nii...
# (91, 109, 3)
# working on M19_002_S_4219_normalized-Z.nii...
# (91, 109, 3)
# working on M34_100_S_2351_normalized-Z.nii...
# (91, 109, 3)
# working on M345_130_S_2391_normalized-Z.nii...
# (91, 109, 3)
# working on M258_031_S_4005_normalized-Z.nii...
# (91, 109, 3)
# working on M32_130_S_4250_normalized-Z.nii...
# (91, 109, 3)
# working on M157_012_S_4987_normalized-Z.nii...
# (91, 109, 3)
# working on M180_130_S_4605_normalized-Z.nii...
# (91, 109, 3)
# working on M127_006_S_4713_normalized-Z.nii...
# (91, 109, 3)
# working on M296_031_S_4721_normalized-Z.nii...
# (91, 109, 3)
# working on M218_018_S_4868_normalized-Z.nii...
# (91, 109, 3)
# working on M339_129_S_4220_normalized-Z.nii...
# (91, 109, 3)
# working on M20_002_S_4171_normalized-Z.nii...
# (91, 109, 3)
# working on M320_053_S_4661_normalized-Z.nii...
# (91, 109, 3)
# working on Normal...
# working on N51_002_S_0295_normalized-Z.nii...
# (91, 109, 3)
# working on N59_002_S_1261_normalized-Z.nii...
# (91, 109, 3)
# working on N101_053_S_4578_normalized-Z.nii...
# (91, 109, 3)
# working on N17_012_S_4643_normalized-Z.nii...
# (91, 109, 3)
# working on N69_130_S_4343_normalized-Z.nii...
# (91, 109, 3)
# working on N138_013_S_4731_normalized-Z.nii...
# (91, 109, 3)
# working on N26_006_S_4449_normalized-Z.nii...
# (91, 109, 3)
# working on N141_018_S_4257_normalized-Z.nii...
# (91, 109, 3)
# working on N3_136_S_4269_normalized-Z.nii...
# (91, 109, 3)
# working on N162_019_S_4367_normalized-Z.nii...
# (91, 109, 3)
# working on N28_002_S_4213_normalized-Z.nii...
# (91, 109, 3)
# working on N27_002_S_1280_normalized-Z.nii...
# (91, 109, 3)
# working on N135_013_S_4616_normalized-Z.nii...
# (91, 109, 3)
# working on N114_010_S_4442_normalized-Z.nii...
# (91, 109, 3)
# working on N13_100_S_4469_normalized-Z.nii...
# (91, 109, 3)
# working on N35_018_S_4400_normalized-Z.nii...
# (91, 109, 3)
# working on N6_129_S_4422_normalized-Z.nii...
# (91, 109, 3)
# working on N86_129_S_4369_normalized-Z.nii...
# (91, 109, 3)
# working on N81_006_S_0731_normalized-Z.nii...
# (91, 109, 3)
# working on N119_012_S_4026_normalized-Z.nii...
# (91, 109, 3)
# working on N29_006_S_4485_normalized-Z.nii...
# (91, 109, 3)
# working on N4_136_S_0186_normalized-Z.nii...
# (91, 109, 3)
# working on N1_136_S_4727_normalized-Z.nii...
# (91, 109, 3)
# working on N117_031_S_4496_normalized-Z.nii...
# (91, 109, 3)
# working on N77_002_S_4270_normalized-Z.nii...
# (91, 109, 3)
# working on N145_018_S_4349_normalized-Z.nii...
# (91, 109, 3)
# working on N54_002_S_0413_normalized-Z.nii...
# (91, 109, 3)
# working on N168_031_S_4032_normalized-Z.nii...
# (91, 109, 3)
# working on N72_002_S_4262_normalized-Z.nii...
# (91, 109, 3)
# working on N38_031_S_4218_normalized-Z.nii...
# (91, 109, 3)
# working on N122_012_S_4545_normalized-Z.nii...
# (91, 109, 3)
# working on N11_100_S_5246_normalized-Z.nii...
# (91, 109, 3)
# working on N39_031_S_4474_normalized-Z.nii...
# (91, 109, 3)
# working on N132_013_S_4580_normalized-Z.nii...
# (91, 109, 3)
# working on N42_130_S_4352_normalized-Z.nii...
# (91, 109, 3)
# working on N7_129_S_4396_normalized-Z.nii...
# (91, 109, 3)
# working on N30_010_S_4345_normalized-Z.nii...
# (91, 109, 3)
# working on N20_002_S_4225_normalized-Z.nii...
# (91, 109, 3)
# working on N50_136_S_4726_normalized-Z.nii...
# (91, 109, 3)
# working on N90_006_S_4357_normalized-Z.nii...
# (91, 109, 3)
# working on N56_002_S_0685_normalized-Z.nii...
# (91, 109, 3)
# working on N149_18_S_4399_normalized-Z.nii...
# (91, 109, 3)
# working on N2_136_S_4433_normalized-Z.nii...
# (91, 109, 3)
# working on N76_002_S_4264_normalized-Z.nii...
# (91, 109, 3)
# working on N128_013_S_4579_normalized-Z.nii...
# (91, 109, 3)
# working on N14_006_S_4150_normalized-Z.nii...
# (91, 109, 3)
# working on N158_019_S_4367_normalized-Z.nii...
# (91, 109, 3)
# working on N139_018_S_4257_normalized-Z.nii...
# (91, 109, 3)
# working on N165_031_S_4021_normalized-Z.nii...
# (91, 109, 3)
# working on N8_129_S_4371_normalized-Z.nii...
# (91, 109, 3)
# working on N10_129_S_0778_normalized-Z.nii...
# (91, 109, 3)
# working on N12_100_S_4511_normalized-Z.nii...
# (91, 109, 3)
